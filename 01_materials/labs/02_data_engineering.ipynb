# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
stock = yf.Ticker("AAPL")
px = stock.history(start = "2013-12-01", end = "2024-02-01")

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file).sample(50, random_state=42)

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    px = (stock
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))
          .reset_index()   # Reset index to get date as a column
          .assign(ticker = row['ticker']))    # Add ticker
    
    if px.shape[0] == 0:
        print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
        continue
    print(f'Downloaded {px.shape}.')
    px_list.append(px)
px_dt = pd.concat(px_list, axis = 0)
print(f'Final shape {px_dt.shape}.')
# Out:
# Processing JCI
# Downloaded (2558, 9).
# Processing BSX
# Downloaded (2558, 9).
# Processing LIN
# Downloaded (2558, 9).
# Processing DOW
# Downloaded (1226, 9).
# Processing CVX
# Downloaded (2558, 9).
# Processing KHC
# Downloaded (2159, 9).
# Processing RL
# Downloaded (2558, 9).
# Processing ED
# Downloaded (2558, 9).
# Processing BX
# Downloaded (2558, 9).
# Processing IBM
# Downloaded (2558, 9).
# Processing A
# Downloaded (2558, 9).
# Processing FIS
# Downloaded (2558, 9).
# Processing MAS
# Downloaded (2558, 9).
# Processing CPB
# Downloaded (2558, 9).
# Processing PNW
# Downloaded (2558, 9).
# Processing QCOM
# Downloaded (2558, 9).
# Processing YUM
# Downloaded (2558, 9).
# Processing AWK
# Downloaded (2558, 9).
# Processing MU
# Downloaded (2558, 9).
# Processing RCL
# Downloaded (2558, 9).
# Processing WTW
# Downloaded (2558, 9).
# Processing GWW
# Downloaded (2558, 9).
# Processing HAS
# Downloaded (2558, 9).
# Processing PEAK
# $PEAK: possibly delisted; No timezone found
# No data for PEAK
# Processing BR
# Downloaded (2558, 9).
# Processing VLO
# Downloaded (2558, 9).
# Processing VICI
# Downloaded (1530, 9).
# Processing RHI
# Downloaded (2558, 9).
# Processing CRL
# Downloaded (2558, 9).
# Processing NEM
# Downloaded (2558, 9).
# Processing LYB
# Downloaded (2558, 9).
# Processing GS
# Downloaded (2558, 9).
# Processing V
# Downloaded (2558, 9).
# Processing EPAM
# Downloaded (2558, 9).
# Processing ABT
# Downloaded (2558, 9).
# Processing NFLX
# Downloaded (2558, 9).
# Processing KVUE
# Downloaded (187, 9).
# Processing BKNG
# Downloaded (2558, 9).
# Processing IT
# Downloaded (2558, 9).
# Processing BBY
# Downloaded (2558, 9).
# Processing NUE
# Downloaded (2558, 9).
# Processing CBRE
# Downloaded (2558, 9).
# Processing WDC
# Downloaded (2558, 9).
# Processing EXPE
# Downloaded (2558, 9).
# Processing AMGN
# Downloaded (2558, 9).
# Processing BRO
# Downloaded (2558, 9).
# Processing MMM
# Downloaded (2558, 9).
# Processing ABNB
# Downloaded (789, 9).
# Processing MDT
# Downloaded (2558, 9).
# Processing AMZN
# Downloaded (2558, 9).
# Final shape (118443, 9).

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
px_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((118443, 9))csv took 2.404837131500244 seconds.
# Csv file size 14.150957 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd
# Out:
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(
# C:\Users\malku\AppData\Local\Temp\ipykernel_21132\676544213.py:1: DeprecationWarning: The current Dask DataFrame implementation is deprecated.
# In a future release, Dask DataFrame will use new implementation that
# contains several improvements including a logical query planning.
# The user-facing DataFrame API will remain unchanged.
#
# The new implementation is already available and can be enabled by
# installing the dask-expr library:
#
#     $ pip install dask-expr
#
# and turning the query planning option on:
#
#     >>> import dask
#     >>> dask.config.set({'dataframe.query-planning': True})
#     >>> import dask.dataframe as dd
#
# API documentation for the new implementation is available at
# https://docs.dask.org/en/stable/dask-expr-api.html
#
# Any feedback can be reported on the Dask issue tracker
# https://github.com/dask/dask/issues
#
#   import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((118443, 9)) to parquet took 1.1379926204681396 seconds.
# Parquet file size 5.552809 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in px_dt.ticker.unique():
    ticker_dt = px_dt[px_dt.ticker == ticker]
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year)
    for yr in ticker_dt.year.unique():
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dt.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
import numpy as np
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
).assign(
    returns = lambda x: x['Close']/x['Close_lag_1'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))
# Out:
# C:\Users\malku\AppData\Local\Temp\ipykernel_21132\3091835559.py:2: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                             Date     Open     High      Low    Close Volume Dividends Stock Splits   year Close_lag_1  returns positive_return
# npartitions=49
# A               datetime64[ns, America/New_York]  float64  float64  float64  float64  int64   float64      float64  int32     float64  float64           int32
# ABNB                                         ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# ...                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# Dask Name: assign, 18 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2013-12-02 00:00:00-05:00   34.995831   35.126727   34.760212
# A      2013-12-03 00:00:00-05:00   34.635870   34.799495   34.400251
# A      2013-12-04 00:00:00-05:00   34.583484   35.231436   34.504947
# A      2013-12-05 00:00:00-05:00   34.917279   35.211801   34.766746
# A      2013-12-06 00:00:00-05:00   35.185644   35.951400   35.185644
# ...                          ...         ...         ...         ...
# YUM    2024-01-25 00:00:00-05:00  128.551783  129.027053  127.274475
# YUM    2024-01-26 00:00:00-05:00  128.640891  129.403315  127.403198
# YUM    2024-01-29 00:00:00-05:00  127.828973  129.264694  127.026935
# YUM    2024-01-30 00:00:00-05:00  129.076550  129.928083  128.304230
# YUM    2024-01-31 00:00:00-05:00  130.155828  130.680609  127.987387
#
#              Close   Volume  Dividends  Stock Splits  year  Close_lag_1  \
# ticker
# A        34.825661  2039962        0.0           0.0  2013          NaN
# A        34.642414  3462706        0.0           0.0  2013    34.825661
# A        35.067810  3377288        0.0           0.0  2013    34.642414
# A        35.015453  2530939        0.0           0.0  2013    35.067810
# A        35.885952  4268513        0.0           0.0  2013    35.015453
# ...            ...      ...        ...           ...   ...          ...
# YUM     128.937943  1871700        0.0           0.0  2024   128.165634
# YUM     127.819061  1157000        0.0           0.0  2024   128.937943
# YUM     129.264694  1482100        0.0           0.0  2024   127.819061
# YUM     129.333984  1421500        0.0           0.0  2024   129.264694
# YUM     128.215134  2154200        0.0           0.0  2024   129.333984
#
#          returns  positive_return
# ticker
# A            NaN                0
# A      -0.005262                0
# A       0.012280                1
# A      -0.001493                0
# A       0.024860                1
# ...          ...              ...
# YUM     0.006026                1
# YUM    -0.008678                0
# YUM     0.011310                1
# YUM     0.000536                1
# YUM    -0.008651                0
#
# [118443 rows x 12 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before start
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %%
FEATURES_DATA = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(FEATURES_DATA, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Below, we demonstrate how our class implementation works.
#
# Before we begin, clean the price directory (we will download everything again).

# %%
# CLean up before start

if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %% [markdown]
# Now, instantiate a DataManager object and download all the data.

# %%
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-06-27 09:57:40,692, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-06-27 09:57:40,692, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-06-27 09:57:40,692, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-06-27 09:57:40,692, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-06-27 09:57:40,718, data_manager.py, 58, INFO, Processing all tickers
# 2024-06-27 09:57:40,718, data_manager.py, 58, INFO, Processing all tickers
# 2024-06-27 09:57:40,724, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-06-27 09:57:40,724, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-06-27 09:57:40,728, data_manager.py, 108, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-06-27
# 2024-06-27 09:57:40,728, data_manager.py, 108, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:57:41,236, data_manager.py, 82, INFO, Saving data for MMM by year
# 2024-06-27 09:57:41,236, data_manager.py, 82, INFO, Saving data for MMM by year
# 2024-06-27 09:57:42,709, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-06-27 09:57:42,709, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-06-27 09:57:42,712, data_manager.py, 108, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-06-27
# 2024-06-27 09:57:42,712, data_manager.py, 108, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:57:43,091, data_manager.py, 82, INFO, Saving data for AOS by year
# 2024-06-27 09:57:43,091, data_manager.py, 82, INFO, Saving data for AOS by year
# 2024-06-27 09:57:44,569, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-06-27 09:57:44,569, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-06-27 09:57:44,571, data_manager.py, 108, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-06-27
# 2024-06-27 09:57:44,571, data_manager.py, 108, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:57:45,032, data_manager.py, 82, INFO, Saving data for ABT by year
# 2024-06-27 09:57:45,032, data_manager.py, 82, INFO, Saving data for ABT by year
# 2024-06-27 09:57:46,501, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-06-27 09:57:46,501, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-06-27 09:57:46,501, data_manager.py, 108, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-06-27
# 2024-06-27 09:57:46,501, data_manager.py, 108, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:57:46,763, data_manager.py, 82, INFO, Saving data for ABBV by year
# 2024-06-27 09:57:46,763, data_manager.py, 82, INFO, Saving data for ABBV by year
# 2024-06-27 09:57:47,561, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-06-27 09:57:47,561, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-06-27 09:57:47,561, data_manager.py, 108, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-06-27
# 2024-06-27 09:57:47,561, data_manager.py, 108, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:57:47,897, data_manager.py, 82, INFO, Saving data for ACN by year
# 2024-06-27 09:57:47,897, data_manager.py, 82, INFO, Saving data for ACN by year
# 2024-06-27 09:57:49,263, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-06-27 09:57:49,263, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-06-27 09:57:49,263, data_manager.py, 108, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-06-27
# 2024-06-27 09:57:49,263, data_manager.py, 108, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:57:49,592, data_manager.py, 82, INFO, Saving data for ADBE by year
# 2024-06-27 09:57:49,592, data_manager.py, 82, INFO, Saving data for ADBE by year
# 2024-06-27 09:57:51,142, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-06-27 09:57:51,142, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-06-27 09:57:51,155, data_manager.py, 108, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-06-27
# 2024-06-27 09:57:51,155, data_manager.py, 108, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:57:51,437, data_manager.py, 82, INFO, Saving data for AMD by year
# 2024-06-27 09:57:51,437, data_manager.py, 82, INFO, Saving data for AMD by year
# 2024-06-27 09:57:52,888, data_manager.py, 73, INFO, Processing ticker AES
# 2024-06-27 09:57:52,888, data_manager.py, 73, INFO, Processing ticker AES
# 2024-06-27 09:57:52,888, data_manager.py, 108, INFO, Getting stock price data for AES from 2000-01-01 to 2024-06-27
# 2024-06-27 09:57:52,888, data_manager.py, 108, INFO, Getting stock price data for AES from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:57:53,251, data_manager.py, 82, INFO, Saving data for AES by year
# 2024-06-27 09:57:53,251, data_manager.py, 82, INFO, Saving data for AES by year
# 2024-06-27 09:57:54,666, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-06-27 09:57:54,666, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-06-27 09:57:54,668, data_manager.py, 108, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-06-27
# 2024-06-27 09:57:54,668, data_manager.py, 108, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:57:55,062, data_manager.py, 82, INFO, Saving data for AFL by year
# 2024-06-27 09:57:55,062, data_manager.py, 82, INFO, Saving data for AFL by year
# 2024-06-27 09:57:56,462, data_manager.py, 73, INFO, Processing ticker A
# 2024-06-27 09:57:56,462, data_manager.py, 73, INFO, Processing ticker A
# 2024-06-27 09:57:56,462, data_manager.py, 108, INFO, Getting stock price data for A from 2000-01-01 to 2024-06-27
# 2024-06-27 09:57:56,462, data_manager.py, 108, INFO, Getting stock price data for A from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:57:56,863, data_manager.py, 82, INFO, Saving data for A by year
# 2024-06-27 09:57:56,863, data_manager.py, 82, INFO, Saving data for A by year
# 2024-06-27 09:57:58,259, data_manager.py, 73, INFO, Processing ticker APD
# 2024-06-27 09:57:58,259, data_manager.py, 73, INFO, Processing ticker APD
# 2024-06-27 09:57:58,275, data_manager.py, 108, INFO, Getting stock price data for APD from 2000-01-01 to 2024-06-27
# 2024-06-27 09:57:58,275, data_manager.py, 108, INFO, Getting stock price data for APD from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:57:58,663, data_manager.py, 82, INFO, Saving data for APD by year
# 2024-06-27 09:57:58,663, data_manager.py, 82, INFO, Saving data for APD by year
# 2024-06-27 09:58:00,054, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-06-27 09:58:00,054, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-06-27 09:58:00,054, data_manager.py, 108, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:00,054, data_manager.py, 108, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:00,243, data_manager.py, 82, INFO, Saving data for ABNB by year
# 2024-06-27 09:58:00,243, data_manager.py, 82, INFO, Saving data for ABNB by year
# 2024-06-27 09:58:00,536, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-06-27 09:58:00,536, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-06-27 09:58:00,539, data_manager.py, 108, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:00,539, data_manager.py, 108, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:00,788, data_manager.py, 82, INFO, Saving data for AKAM by year
# 2024-06-27 09:58:00,788, data_manager.py, 82, INFO, Saving data for AKAM by year
# 2024-06-27 09:58:02,272, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-06-27 09:58:02,272, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-06-27 09:58:02,272, data_manager.py, 108, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:02,272, data_manager.py, 108, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:02,671, data_manager.py, 82, INFO, Saving data for ALB by year
# 2024-06-27 09:58:02,671, data_manager.py, 82, INFO, Saving data for ALB by year
# 2024-06-27 09:58:04,135, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-06-27 09:58:04,135, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-06-27 09:58:04,135, data_manager.py, 108, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:04,135, data_manager.py, 108, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:04,557, data_manager.py, 82, INFO, Saving data for ARE by year
# 2024-06-27 09:58:04,557, data_manager.py, 82, INFO, Saving data for ARE by year
# 2024-06-27 09:58:05,922, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-06-27 09:58:05,922, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-06-27 09:58:05,922, data_manager.py, 108, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:05,922, data_manager.py, 108, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:06,204, data_manager.py, 82, INFO, Saving data for ALGN by year
# 2024-06-27 09:58:06,204, data_manager.py, 82, INFO, Saving data for ALGN by year
# 2024-06-27 09:58:07,683, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-06-27 09:58:07,683, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-06-27 09:58:07,685, data_manager.py, 108, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:07,685, data_manager.py, 108, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:07,939, data_manager.py, 82, INFO, Saving data for ALLE by year
# 2024-06-27 09:58:07,939, data_manager.py, 82, INFO, Saving data for ALLE by year
# 2024-06-27 09:58:09,060, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-06-27 09:58:09,060, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-06-27 09:58:09,069, data_manager.py, 108, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:09,069, data_manager.py, 108, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:09,563, data_manager.py, 82, INFO, Saving data for LNT by year
# 2024-06-27 09:58:09,563, data_manager.py, 82, INFO, Saving data for LNT by year
# 2024-06-27 09:58:10,998, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-06-27 09:58:10,998, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-06-27 09:58:10,998, data_manager.py, 108, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:10,998, data_manager.py, 108, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:11,385, data_manager.py, 82, INFO, Saving data for ALL by year
# 2024-06-27 09:58:11,385, data_manager.py, 82, INFO, Saving data for ALL by year
# 2024-06-27 09:58:12,696, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-06-27 09:58:12,696, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-06-27 09:58:12,696, data_manager.py, 108, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:12,696, data_manager.py, 108, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:13,147, data_manager.py, 82, INFO, Saving data for GOOGL by year
# 2024-06-27 09:58:13,147, data_manager.py, 82, INFO, Saving data for GOOGL by year
# 2024-06-27 09:58:14,346, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-06-27 09:58:14,346, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-06-27 09:58:14,346, data_manager.py, 108, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:14,346, data_manager.py, 108, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:14,778, data_manager.py, 82, INFO, Saving data for GOOG by year
# 2024-06-27 09:58:14,778, data_manager.py, 82, INFO, Saving data for GOOG by year
# 2024-06-27 09:58:15,909, data_manager.py, 73, INFO, Processing ticker MO
# 2024-06-27 09:58:15,909, data_manager.py, 73, INFO, Processing ticker MO
# 2024-06-27 09:58:15,909, data_manager.py, 108, INFO, Getting stock price data for MO from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:15,909, data_manager.py, 108, INFO, Getting stock price data for MO from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:16,424, data_manager.py, 82, INFO, Saving data for MO by year
# 2024-06-27 09:58:16,424, data_manager.py, 82, INFO, Saving data for MO by year
# 2024-06-27 09:58:17,672, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-06-27 09:58:17,672, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-06-27 09:58:17,688, data_manager.py, 108, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:17,688, data_manager.py, 108, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:18,072, data_manager.py, 82, INFO, Saving data for AMZN by year
# 2024-06-27 09:58:18,072, data_manager.py, 82, INFO, Saving data for AMZN by year
# 2024-06-27 09:58:19,336, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-06-27 09:58:19,336, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-06-27 09:58:19,336, data_manager.py, 108, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:19,336, data_manager.py, 108, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:19,601, data_manager.py, 82, INFO, Saving data for AMCR by year
# 2024-06-27 09:58:19,601, data_manager.py, 82, INFO, Saving data for AMCR by year
# 2024-06-27 09:58:20,250, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-06-27 09:58:20,250, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-06-27 09:58:20,250, data_manager.py, 108, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:20,250, data_manager.py, 108, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:20,599, data_manager.py, 82, INFO, Saving data for AEE by year
# 2024-06-27 09:58:20,599, data_manager.py, 82, INFO, Saving data for AEE by year
# 2024-06-27 09:58:21,824, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-06-27 09:58:21,824, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-06-27 09:58:21,825, data_manager.py, 108, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:21,825, data_manager.py, 108, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:22,112, data_manager.py, 82, INFO, Saving data for AAL by year
# 2024-06-27 09:58:22,112, data_manager.py, 82, INFO, Saving data for AAL by year
# 2024-06-27 09:58:23,088, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-06-27 09:58:23,088, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-06-27 09:58:23,090, data_manager.py, 108, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:23,090, data_manager.py, 108, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:23,473, data_manager.py, 82, INFO, Saving data for AEP by year
# 2024-06-27 09:58:23,473, data_manager.py, 82, INFO, Saving data for AEP by year
# 2024-06-27 09:58:24,875, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-06-27 09:58:24,875, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-06-27 09:58:24,875, data_manager.py, 108, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:24,875, data_manager.py, 108, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:25,407, data_manager.py, 82, INFO, Saving data for AXP by year
# 2024-06-27 09:58:25,407, data_manager.py, 82, INFO, Saving data for AXP by year
# 2024-06-27 09:58:26,705, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-06-27 09:58:26,705, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-06-27 09:58:26,705, data_manager.py, 108, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:26,705, data_manager.py, 108, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:27,122, data_manager.py, 82, INFO, Saving data for AIG by year
# 2024-06-27 09:58:27,122, data_manager.py, 82, INFO, Saving data for AIG by year
# 2024-06-27 09:58:28,435, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-06-27 09:58:28,435, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-06-27 09:58:28,435, data_manager.py, 108, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:28,435, data_manager.py, 108, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:28,766, data_manager.py, 82, INFO, Saving data for AMT by year
# 2024-06-27 09:58:28,766, data_manager.py, 82, INFO, Saving data for AMT by year
# 2024-06-27 09:58:30,017, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-06-27 09:58:30,017, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-06-27 09:58:30,032, data_manager.py, 108, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:30,032, data_manager.py, 108, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:30,350, data_manager.py, 82, INFO, Saving data for AWK by year
# 2024-06-27 09:58:30,350, data_manager.py, 82, INFO, Saving data for AWK by year
# 2024-06-27 09:58:31,215, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-06-27 09:58:31,215, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-06-27 09:58:31,215, data_manager.py, 108, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:31,215, data_manager.py, 108, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:31,529, data_manager.py, 82, INFO, Saving data for AMP by year
# 2024-06-27 09:58:31,529, data_manager.py, 82, INFO, Saving data for AMP by year
# 2024-06-27 09:58:32,562, data_manager.py, 73, INFO, Processing ticker AME
# 2024-06-27 09:58:32,562, data_manager.py, 73, INFO, Processing ticker AME
# 2024-06-27 09:58:32,564, data_manager.py, 108, INFO, Getting stock price data for AME from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:32,564, data_manager.py, 108, INFO, Getting stock price data for AME from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:33,044, data_manager.py, 82, INFO, Saving data for AME by year
# 2024-06-27 09:58:33,044, data_manager.py, 82, INFO, Saving data for AME by year
# 2024-06-27 09:58:34,324, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-06-27 09:58:34,324, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-06-27 09:58:34,324, data_manager.py, 108, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:34,324, data_manager.py, 108, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:34,659, data_manager.py, 82, INFO, Saving data for AMGN by year
# 2024-06-27 09:58:34,659, data_manager.py, 82, INFO, Saving data for AMGN by year
# 2024-06-27 09:58:35,954, data_manager.py, 73, INFO, Processing ticker APH
# 2024-06-27 09:58:35,954, data_manager.py, 73, INFO, Processing ticker APH
# 2024-06-27 09:58:35,954, data_manager.py, 108, INFO, Getting stock price data for APH from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:35,954, data_manager.py, 108, INFO, Getting stock price data for APH from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:36,570, data_manager.py, 82, INFO, Saving data for APH by year
# 2024-06-27 09:58:36,570, data_manager.py, 82, INFO, Saving data for APH by year
# 2024-06-27 09:58:37,857, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-06-27 09:58:37,857, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-06-27 09:58:37,859, data_manager.py, 108, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:37,859, data_manager.py, 108, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:38,217, data_manager.py, 82, INFO, Saving data for ADI by year
# 2024-06-27 09:58:38,217, data_manager.py, 82, INFO, Saving data for ADI by year
# 2024-06-27 09:58:39,515, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-06-27 09:58:39,515, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-06-27 09:58:39,515, data_manager.py, 108, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:39,515, data_manager.py, 108, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:39,816, data_manager.py, 82, INFO, Saving data for ANSS by year
# 2024-06-27 09:58:39,816, data_manager.py, 82, INFO, Saving data for ANSS by year
# 2024-06-27 09:58:41,103, data_manager.py, 73, INFO, Processing ticker AON
# 2024-06-27 09:58:41,103, data_manager.py, 73, INFO, Processing ticker AON
# 2024-06-27 09:58:41,106, data_manager.py, 108, INFO, Getting stock price data for AON from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:41,106, data_manager.py, 108, INFO, Getting stock price data for AON from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:41,595, data_manager.py, 82, INFO, Saving data for AON by year
# 2024-06-27 09:58:41,595, data_manager.py, 82, INFO, Saving data for AON by year
# 2024-06-27 09:58:42,867, data_manager.py, 73, INFO, Processing ticker APA
# 2024-06-27 09:58:42,867, data_manager.py, 73, INFO, Processing ticker APA
# 2024-06-27 09:58:42,869, data_manager.py, 108, INFO, Getting stock price data for APA from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:42,869, data_manager.py, 108, INFO, Getting stock price data for APA from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:43,343, data_manager.py, 82, INFO, Saving data for APA by year
# 2024-06-27 09:58:43,343, data_manager.py, 82, INFO, Saving data for APA by year
# 2024-06-27 09:58:44,634, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-06-27 09:58:44,634, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-06-27 09:58:44,637, data_manager.py, 108, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:44,637, data_manager.py, 108, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:45,037, data_manager.py, 82, INFO, Saving data for AAPL by year
# 2024-06-27 09:58:45,037, data_manager.py, 82, INFO, Saving data for AAPL by year
# 2024-06-27 09:58:46,302, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-06-27 09:58:46,302, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-06-27 09:58:46,302, data_manager.py, 108, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:46,302, data_manager.py, 108, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:46,701, data_manager.py, 82, INFO, Saving data for AMAT by year
# 2024-06-27 09:58:46,701, data_manager.py, 82, INFO, Saving data for AMAT by year
# 2024-06-27 09:58:48,026, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-06-27 09:58:48,026, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-06-27 09:58:48,027, data_manager.py, 108, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:48,027, data_manager.py, 108, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:48,315, data_manager.py, 82, INFO, Saving data for APTV by year
# 2024-06-27 09:58:48,315, data_manager.py, 82, INFO, Saving data for APTV by year
# 2024-06-27 09:58:49,064, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-06-27 09:58:49,064, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-06-27 09:58:49,064, data_manager.py, 108, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:49,064, data_manager.py, 108, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:49,396, data_manager.py, 82, INFO, Saving data for ACGL by year
# 2024-06-27 09:58:49,396, data_manager.py, 82, INFO, Saving data for ACGL by year
# 2024-06-27 09:58:50,805, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-06-27 09:58:50,805, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-06-27 09:58:50,807, data_manager.py, 108, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:50,807, data_manager.py, 108, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:51,194, data_manager.py, 82, INFO, Saving data for ADM by year
# 2024-06-27 09:58:51,194, data_manager.py, 82, INFO, Saving data for ADM by year
# 2024-06-27 09:58:52,792, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-06-27 09:58:52,792, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-06-27 09:58:52,798, data_manager.py, 108, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:52,798, data_manager.py, 108, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:53,009, data_manager.py, 82, INFO, Saving data for ANET by year
# 2024-06-27 09:58:53,009, data_manager.py, 82, INFO, Saving data for ANET by year
# 2024-06-27 09:58:53,627, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-06-27 09:58:53,627, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-06-27 09:58:53,629, data_manager.py, 108, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:53,629, data_manager.py, 108, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:54,057, data_manager.py, 82, INFO, Saving data for AJG by year
# 2024-06-27 09:58:54,057, data_manager.py, 82, INFO, Saving data for AJG by year
# 2024-06-27 09:58:55,502, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-06-27 09:58:55,502, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-06-27 09:58:55,504, data_manager.py, 108, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:55,504, data_manager.py, 108, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:55,870, data_manager.py, 82, INFO, Saving data for AIZ by year
# 2024-06-27 09:58:55,870, data_manager.py, 82, INFO, Saving data for AIZ by year
# 2024-06-27 09:58:57,110, data_manager.py, 73, INFO, Processing ticker T
# 2024-06-27 09:58:57,110, data_manager.py, 73, INFO, Processing ticker T
# 2024-06-27 09:58:57,112, data_manager.py, 108, INFO, Getting stock price data for T from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:57,112, data_manager.py, 108, INFO, Getting stock price data for T from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:57,517, data_manager.py, 82, INFO, Saving data for T by year
# 2024-06-27 09:58:57,517, data_manager.py, 82, INFO, Saving data for T by year
# 2024-06-27 09:58:59,072, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-06-27 09:58:59,072, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-06-27 09:58:59,074, data_manager.py, 108, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-06-27
# 2024-06-27 09:58:59,074, data_manager.py, 108, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:58:59,479, data_manager.py, 82, INFO, Saving data for ATO by year
# 2024-06-27 09:58:59,479, data_manager.py, 82, INFO, Saving data for ATO by year
# 2024-06-27 09:59:00,939, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-06-27 09:59:00,939, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-06-27 09:59:00,941, data_manager.py, 108, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:00,941, data_manager.py, 108, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:01,344, data_manager.py, 82, INFO, Saving data for ADSK by year
# 2024-06-27 09:59:01,344, data_manager.py, 82, INFO, Saving data for ADSK by year
# 2024-06-27 09:59:02,893, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-06-27 09:59:02,893, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-06-27 09:59:02,896, data_manager.py, 108, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:02,896, data_manager.py, 108, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:03,340, data_manager.py, 82, INFO, Saving data for ADP by year
# 2024-06-27 09:59:03,340, data_manager.py, 82, INFO, Saving data for ADP by year
# 2024-06-27 09:59:04,935, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-06-27 09:59:04,935, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-06-27 09:59:04,935, data_manager.py, 108, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:04,935, data_manager.py, 108, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:05,239, data_manager.py, 82, INFO, Saving data for AZO by year
# 2024-06-27 09:59:05,239, data_manager.py, 82, INFO, Saving data for AZO by year
# 2024-06-27 09:59:06,715, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-06-27 09:59:06,715, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-06-27 09:59:06,715, data_manager.py, 108, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:06,715, data_manager.py, 108, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:07,150, data_manager.py, 82, INFO, Saving data for AVB by year
# 2024-06-27 09:59:07,150, data_manager.py, 82, INFO, Saving data for AVB by year
# 2024-06-27 09:59:08,538, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-06-27 09:59:08,538, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-06-27 09:59:08,540, data_manager.py, 108, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:08,540, data_manager.py, 108, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:08,946, data_manager.py, 82, INFO, Saving data for AVY by year
# 2024-06-27 09:59:08,946, data_manager.py, 82, INFO, Saving data for AVY by year
# 2024-06-27 09:59:10,534, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-06-27 09:59:10,534, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-06-27 09:59:10,535, data_manager.py, 108, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:10,535, data_manager.py, 108, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:10,922, data_manager.py, 82, INFO, Saving data for AXON by year
# 2024-06-27 09:59:10,922, data_manager.py, 82, INFO, Saving data for AXON by year
# 2024-06-27 09:59:12,249, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-06-27 09:59:12,249, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-06-27 09:59:12,251, data_manager.py, 108, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:12,251, data_manager.py, 108, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:12,651, data_manager.py, 82, INFO, Saving data for BKR by year
# 2024-06-27 09:59:12,651, data_manager.py, 82, INFO, Saving data for BKR by year
# 2024-06-27 09:59:14,007, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-06-27 09:59:14,007, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-06-27 09:59:14,008, data_manager.py, 108, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:14,008, data_manager.py, 108, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:14,497, data_manager.py, 82, INFO, Saving data for BALL by year
# 2024-06-27 09:59:14,497, data_manager.py, 82, INFO, Saving data for BALL by year
# 2024-06-27 09:59:15,844, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-06-27 09:59:15,844, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-06-27 09:59:15,846, data_manager.py, 108, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:15,846, data_manager.py, 108, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:16,364, data_manager.py, 82, INFO, Saving data for BAC by year
# 2024-06-27 09:59:16,364, data_manager.py, 82, INFO, Saving data for BAC by year
# 2024-06-27 09:59:17,736, data_manager.py, 73, INFO, Processing ticker BK
# 2024-06-27 09:59:17,736, data_manager.py, 73, INFO, Processing ticker BK
# 2024-06-27 09:59:17,738, data_manager.py, 108, INFO, Getting stock price data for BK from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:17,738, data_manager.py, 108, INFO, Getting stock price data for BK from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:18,228, data_manager.py, 82, INFO, Saving data for BK by year
# 2024-06-27 09:59:18,228, data_manager.py, 82, INFO, Saving data for BK by year
# 2024-06-27 09:59:19,583, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-06-27 09:59:19,583, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-06-27 09:59:19,585, data_manager.py, 108, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:19,585, data_manager.py, 108, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:19,989, data_manager.py, 82, INFO, Saving data for BBWI by year
# 2024-06-27 09:59:19,989, data_manager.py, 82, INFO, Saving data for BBWI by year
# 2024-06-27 09:59:21,430, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-06-27 09:59:21,430, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-06-27 09:59:21,433, data_manager.py, 108, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:21,433, data_manager.py, 108, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:21,919, data_manager.py, 82, INFO, Saving data for BAX by year
# 2024-06-27 09:59:21,919, data_manager.py, 82, INFO, Saving data for BAX by year
# 2024-06-27 09:59:23,469, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-06-27 09:59:23,469, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-06-27 09:59:23,472, data_manager.py, 108, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:23,472, data_manager.py, 108, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:23,933, data_manager.py, 82, INFO, Saving data for BDX by year
# 2024-06-27 09:59:23,933, data_manager.py, 82, INFO, Saving data for BDX by year
# 2024-06-27 09:59:25,368, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-06-27 09:59:25,368, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-06-27 09:59:25,369, data_manager.py, 108, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:25,369, data_manager.py, 108, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-06-27 09:59:26,816, data_manager.py, 82, INFO, Saving data for BRK.B by year
# 2024-06-27 09:59:26,816, data_manager.py, 82, INFO, Saving data for BRK.B by year
# 2024-06-27 09:59:26,819, data_manager.py, 100, WARNING, No data found for BRK.B
# 2024-06-27 09:59:26,819, data_manager.py, 100, WARNING, No data found for BRK.B
# 2024-06-27 09:59:26,823, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-06-27 09:59:26,823, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-06-27 09:59:26,825, data_manager.py, 108, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:26,825, data_manager.py, 108, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:27,312, data_manager.py, 82, INFO, Saving data for BBY by year
# 2024-06-27 09:59:27,312, data_manager.py, 82, INFO, Saving data for BBY by year
# 2024-06-27 09:59:28,860, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-06-27 09:59:28,860, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-06-27 09:59:28,862, data_manager.py, 108, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:28,862, data_manager.py, 108, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:29,205, data_manager.py, 82, INFO, Saving data for BIO by year
# 2024-06-27 09:59:29,205, data_manager.py, 82, INFO, Saving data for BIO by year
# 2024-06-27 09:59:30,855, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-06-27 09:59:30,855, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-06-27 09:59:30,855, data_manager.py, 108, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:30,855, data_manager.py, 108, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:31,221, data_manager.py, 82, INFO, Saving data for TECH by year
# 2024-06-27 09:59:31,221, data_manager.py, 82, INFO, Saving data for TECH by year
# 2024-06-27 09:59:32,829, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-06-27 09:59:32,829, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-06-27 09:59:32,829, data_manager.py, 108, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:32,829, data_manager.py, 108, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:33,227, data_manager.py, 82, INFO, Saving data for BIIB by year
# 2024-06-27 09:59:33,227, data_manager.py, 82, INFO, Saving data for BIIB by year
# 2024-06-27 09:59:34,914, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-06-27 09:59:34,914, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-06-27 09:59:34,914, data_manager.py, 108, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:34,914, data_manager.py, 108, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:35,287, data_manager.py, 82, INFO, Saving data for BLK by year
# 2024-06-27 09:59:35,287, data_manager.py, 82, INFO, Saving data for BLK by year
# 2024-06-27 09:59:36,880, data_manager.py, 73, INFO, Processing ticker BX
# 2024-06-27 09:59:36,880, data_manager.py, 73, INFO, Processing ticker BX
# 2024-06-27 09:59:36,880, data_manager.py, 108, INFO, Getting stock price data for BX from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:36,880, data_manager.py, 108, INFO, Getting stock price data for BX from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:37,263, data_manager.py, 82, INFO, Saving data for BX by year
# 2024-06-27 09:59:37,263, data_manager.py, 82, INFO, Saving data for BX by year
# 2024-06-27 09:59:38,377, data_manager.py, 73, INFO, Processing ticker BA
# 2024-06-27 09:59:38,377, data_manager.py, 73, INFO, Processing ticker BA
# 2024-06-27 09:59:38,377, data_manager.py, 108, INFO, Getting stock price data for BA from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:38,377, data_manager.py, 108, INFO, Getting stock price data for BA from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:38,770, data_manager.py, 82, INFO, Saving data for BA by year
# 2024-06-27 09:59:38,770, data_manager.py, 82, INFO, Saving data for BA by year
# 2024-06-27 09:59:40,278, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-06-27 09:59:40,278, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-06-27 09:59:40,278, data_manager.py, 108, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:40,278, data_manager.py, 108, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:40,921, data_manager.py, 82, INFO, Saving data for BKNG by year
# 2024-06-27 09:59:40,921, data_manager.py, 82, INFO, Saving data for BKNG by year
# 2024-06-27 09:59:42,449, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-06-27 09:59:42,449, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-06-27 09:59:42,449, data_manager.py, 108, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:42,449, data_manager.py, 108, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:42,932, data_manager.py, 82, INFO, Saving data for BWA by year
# 2024-06-27 09:59:42,932, data_manager.py, 82, INFO, Saving data for BWA by year
# 2024-06-27 09:59:44,452, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-06-27 09:59:44,452, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-06-27 09:59:44,452, data_manager.py, 108, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:44,452, data_manager.py, 108, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:44,815, data_manager.py, 82, INFO, Saving data for BXP by year
# 2024-06-27 09:59:44,815, data_manager.py, 82, INFO, Saving data for BXP by year
# 2024-06-27 09:59:46,376, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-06-27 09:59:46,376, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-06-27 09:59:46,376, data_manager.py, 108, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:46,376, data_manager.py, 108, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:46,760, data_manager.py, 82, INFO, Saving data for BSX by year
# 2024-06-27 09:59:46,760, data_manager.py, 82, INFO, Saving data for BSX by year
# 2024-06-27 09:59:48,223, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-06-27 09:59:48,223, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-06-27 09:59:48,239, data_manager.py, 108, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:48,239, data_manager.py, 108, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:48,673, data_manager.py, 82, INFO, Saving data for BMY by year
# 2024-06-27 09:59:48,673, data_manager.py, 82, INFO, Saving data for BMY by year
# 2024-06-27 09:59:50,173, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-06-27 09:59:50,173, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-06-27 09:59:50,175, data_manager.py, 108, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:50,175, data_manager.py, 108, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:50,535, data_manager.py, 82, INFO, Saving data for AVGO by year
# 2024-06-27 09:59:50,535, data_manager.py, 82, INFO, Saving data for AVGO by year
# 2024-06-27 09:59:51,517, data_manager.py, 73, INFO, Processing ticker BR
# 2024-06-27 09:59:51,517, data_manager.py, 73, INFO, Processing ticker BR
# 2024-06-27 09:59:51,517, data_manager.py, 108, INFO, Getting stock price data for BR from 2000-01-01 to 2024-06-27
# 2024-06-27 09:59:51,517, data_manager.py, 108, INFO, Getting stock price data for BR from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 09:59:51,834, data_manager.py, 82, INFO, Saving data for BR by year
# 2024-06-27 09:59:51,834, data_manager.py, 82, INFO, Saving data for BR by year
# 2024-06-27 09:59:52,914, data_manager.py, 73, INFO, Processing ticker BRO
# 2024-06-27 09:59:52,914, data_manager.py, 73, INFO, Processing ticker BRO
# ...
# 2024-06-27 10:11:18,525, data_manager.py, 82, INFO, Saving data for WRB by year
# 2024-06-27 10:11:20,155, data_manager.py, 73, INFO, Processing ticker WAB
# 2024-06-27 10:11:20,155, data_manager.py, 73, INFO, Processing ticker WAB
# 2024-06-27 10:11:20,155, data_manager.py, 108, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:20,155, data_manager.py, 108, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:20,680, data_manager.py, 82, INFO, Saving data for WAB by year
# 2024-06-27 10:11:20,680, data_manager.py, 82, INFO, Saving data for WAB by year
# 2024-06-27 10:11:22,288, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-06-27 10:11:22,288, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-06-27 10:11:22,288, data_manager.py, 108, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:22,288, data_manager.py, 108, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:22,801, data_manager.py, 82, INFO, Saving data for WBA by year
# 2024-06-27 10:11:22,801, data_manager.py, 82, INFO, Saving data for WBA by year
# 2024-06-27 10:11:24,299, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-06-27 10:11:24,299, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-06-27 10:11:24,299, data_manager.py, 108, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:24,299, data_manager.py, 108, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:24,863, data_manager.py, 82, INFO, Saving data for WMT by year
# 2024-06-27 10:11:24,863, data_manager.py, 82, INFO, Saving data for WMT by year
# 2024-06-27 10:11:26,442, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-06-27 10:11:26,442, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-06-27 10:11:26,442, data_manager.py, 108, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:26,442, data_manager.py, 108, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:27,060, data_manager.py, 82, INFO, Saving data for DIS by year
# 2024-06-27 10:11:27,060, data_manager.py, 82, INFO, Saving data for DIS by year
# 2024-06-27 10:11:28,655, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-06-27 10:11:28,655, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-06-27 10:11:28,655, data_manager.py, 108, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:28,655, data_manager.py, 108, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:29,003, data_manager.py, 82, INFO, Saving data for WBD by year
# 2024-06-27 10:11:29,003, data_manager.py, 82, INFO, Saving data for WBD by year
# 2024-06-27 10:11:30,235, data_manager.py, 73, INFO, Processing ticker WM
# 2024-06-27 10:11:30,235, data_manager.py, 73, INFO, Processing ticker WM
# 2024-06-27 10:11:30,235, data_manager.py, 108, INFO, Getting stock price data for WM from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:30,235, data_manager.py, 108, INFO, Getting stock price data for WM from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:30,667, data_manager.py, 82, INFO, Saving data for WM by year
# 2024-06-27 10:11:30,667, data_manager.py, 82, INFO, Saving data for WM by year
# 2024-06-27 10:11:32,148, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-06-27 10:11:32,148, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-06-27 10:11:32,148, data_manager.py, 108, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:32,148, data_manager.py, 108, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:32,514, data_manager.py, 82, INFO, Saving data for WAT by year
# 2024-06-27 10:11:32,514, data_manager.py, 82, INFO, Saving data for WAT by year
# 2024-06-27 10:11:34,025, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-06-27 10:11:34,025, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-06-27 10:11:34,025, data_manager.py, 108, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:34,025, data_manager.py, 108, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:34,630, data_manager.py, 82, INFO, Saving data for WEC by year
# 2024-06-27 10:11:34,630, data_manager.py, 82, INFO, Saving data for WEC by year
# 2024-06-27 10:11:36,226, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-06-27 10:11:36,226, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-06-27 10:11:36,226, data_manager.py, 108, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:36,226, data_manager.py, 108, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:36,756, data_manager.py, 82, INFO, Saving data for WFC by year
# 2024-06-27 10:11:36,756, data_manager.py, 82, INFO, Saving data for WFC by year
# 2024-06-27 10:11:38,354, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-06-27 10:11:38,354, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-06-27 10:11:38,356, data_manager.py, 108, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:38,356, data_manager.py, 108, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:38,803, data_manager.py, 82, INFO, Saving data for WELL by year
# 2024-06-27 10:11:38,803, data_manager.py, 82, INFO, Saving data for WELL by year
# 2024-06-27 10:11:40,302, data_manager.py, 73, INFO, Processing ticker WST
# 2024-06-27 10:11:40,302, data_manager.py, 73, INFO, Processing ticker WST
# 2024-06-27 10:11:40,302, data_manager.py, 108, INFO, Getting stock price data for WST from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:40,302, data_manager.py, 108, INFO, Getting stock price data for WST from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:40,833, data_manager.py, 82, INFO, Saving data for WST by year
# 2024-06-27 10:11:40,833, data_manager.py, 82, INFO, Saving data for WST by year
# 2024-06-27 10:11:42,296, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-06-27 10:11:42,296, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-06-27 10:11:42,296, data_manager.py, 108, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:42,296, data_manager.py, 108, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:42,745, data_manager.py, 82, INFO, Saving data for WDC by year
# 2024-06-27 10:11:42,745, data_manager.py, 82, INFO, Saving data for WDC by year
# 2024-06-27 10:11:44,193, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-06-27 10:11:44,193, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-06-27 10:11:44,209, data_manager.py, 108, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:44,209, data_manager.py, 108, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:44,493, data_manager.py, 82, INFO, Saving data for WRK by year
# 2024-06-27 10:11:44,493, data_manager.py, 82, INFO, Saving data for WRK by year
# 2024-06-27 10:11:45,075, data_manager.py, 73, INFO, Processing ticker WY
# 2024-06-27 10:11:45,075, data_manager.py, 73, INFO, Processing ticker WY
# 2024-06-27 10:11:45,091, data_manager.py, 108, INFO, Getting stock price data for WY from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:45,091, data_manager.py, 108, INFO, Getting stock price data for WY from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:45,577, data_manager.py, 82, INFO, Saving data for WY by year
# 2024-06-27 10:11:45,577, data_manager.py, 82, INFO, Saving data for WY by year
# 2024-06-27 10:11:47,021, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-06-27 10:11:47,021, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-06-27 10:11:47,033, data_manager.py, 108, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:47,033, data_manager.py, 108, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:47,457, data_manager.py, 82, INFO, Saving data for WHR by year
# 2024-06-27 10:11:47,457, data_manager.py, 82, INFO, Saving data for WHR by year
# 2024-06-27 10:11:48,969, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-06-27 10:11:48,969, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-06-27 10:11:48,971, data_manager.py, 108, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:48,971, data_manager.py, 108, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:49,566, data_manager.py, 82, INFO, Saving data for WMB by year
# 2024-06-27 10:11:49,566, data_manager.py, 82, INFO, Saving data for WMB by year
# 2024-06-27 10:11:51,080, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-06-27 10:11:51,080, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-06-27 10:11:51,080, data_manager.py, 108, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:51,080, data_manager.py, 108, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:51,550, data_manager.py, 82, INFO, Saving data for WTW by year
# 2024-06-27 10:11:51,550, data_manager.py, 82, INFO, Saving data for WTW by year
# 2024-06-27 10:11:52,962, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-06-27 10:11:52,962, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-06-27 10:11:52,962, data_manager.py, 108, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:52,962, data_manager.py, 108, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:53,528, data_manager.py, 82, INFO, Saving data for GWW by year
# 2024-06-27 10:11:53,528, data_manager.py, 82, INFO, Saving data for GWW by year
# 2024-06-27 10:11:55,005, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-06-27 10:11:55,005, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-06-27 10:11:55,007, data_manager.py, 108, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:55,007, data_manager.py, 108, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:55,344, data_manager.py, 82, INFO, Saving data for WYNN by year
# 2024-06-27 10:11:55,344, data_manager.py, 82, INFO, Saving data for WYNN by year
# 2024-06-27 10:11:56,686, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-06-27 10:11:56,686, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-06-27 10:11:56,686, data_manager.py, 108, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:56,686, data_manager.py, 108, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:57,137, data_manager.py, 82, INFO, Saving data for XEL by year
# 2024-06-27 10:11:57,137, data_manager.py, 82, INFO, Saving data for XEL by year
# 2024-06-27 10:11:58,634, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-06-27 10:11:58,634, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-06-27 10:11:58,634, data_manager.py, 108, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:58,634, data_manager.py, 108, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:11:58,932, data_manager.py, 82, INFO, Saving data for XYL by year
# 2024-06-27 10:11:58,932, data_manager.py, 82, INFO, Saving data for XYL by year
# 2024-06-27 10:11:59,764, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-06-27 10:11:59,764, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-06-27 10:11:59,764, data_manager.py, 108, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-06-27
# 2024-06-27 10:11:59,764, data_manager.py, 108, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:12:00,230, data_manager.py, 82, INFO, Saving data for YUM by year
# 2024-06-27 10:12:00,230, data_manager.py, 82, INFO, Saving data for YUM by year
# 2024-06-27 10:12:01,845, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-06-27 10:12:01,845, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-06-27 10:12:01,845, data_manager.py, 108, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-06-27
# 2024-06-27 10:12:01,845, data_manager.py, 108, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:12:02,177, data_manager.py, 82, INFO, Saving data for ZBRA by year
# 2024-06-27 10:12:02,177, data_manager.py, 82, INFO, Saving data for ZBRA by year
# 2024-06-27 10:12:03,690, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-06-27 10:12:03,690, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-06-27 10:12:03,707, data_manager.py, 108, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-06-27
# 2024-06-27 10:12:03,707, data_manager.py, 108, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:12:04,077, data_manager.py, 82, INFO, Saving data for ZBH by year
# 2024-06-27 10:12:04,077, data_manager.py, 82, INFO, Saving data for ZBH by year
# 2024-06-27 10:12:05,520, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-06-27 10:12:05,520, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-06-27 10:12:05,520, data_manager.py, 108, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-06-27
# 2024-06-27 10:12:05,520, data_manager.py, 108, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:12:05,903, data_manager.py, 82, INFO, Saving data for ZION by year
# 2024-06-27 10:12:05,903, data_manager.py, 82, INFO, Saving data for ZION by year
# 2024-06-27 10:12:07,405, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-06-27 10:12:07,405, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-06-27 10:12:07,417, data_manager.py, 108, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-06-27
# 2024-06-27 10:12:07,417, data_manager.py, 108, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-06-27
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-27 10:12:07,717, data_manager.py, 82, INFO, Saving data for ZTS by year
# 2024-06-27 10:12:07,717, data_manager.py, 82, INFO, Saving data for ZTS by year

# %% [markdown]
# Finally, add features to our data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2024-06-27 10:12:08,433, data_manager.py, 117, INFO, Creating features data.
# 2024-06-27 10:12:08,433, data_manager.py, 117, INFO, Creating features data.
# 2024-06-27 10:12:08,433, data_manager.py, 128, INFO, Loading price data from ../../05_src/data/prices/
# 2024-06-27 10:12:08,433, data_manager.py, 128, INFO, Loading price data from ../../05_src/data/prices/
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\core.py:5517: UserWarning: New index has same name as existing, this is a no-op.
#   warnings.warn(
# 2024-06-27 10:12:11,958, data_manager.py, 136, INFO, Creating features
# 2024-06-27 10:12:11,958, data_manager.py, 136, INFO, Creating features
# c:\Yuliia\DSI\scaling_to_production\01_materials\labs\../../05_src\data_manager.py:138: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd
# 2024-06-27 10:12:12,079, data_manager.py, 154, INFO, Creating target
# 2024-06-27 10:12:12,079, data_manager.py, 154, INFO, Creating target
# c:\Yuliia\DSI\scaling_to_production\01_materials\labs\../../05_src\data_manager.py:155: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   self.features = (self.features.groupby('ticker', group_keys=False).apply(
# 2024-06-27 10:12:12,291, data_manager.py, 164, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# 2024-06-27 10:12:12,291, data_manager.py, 164, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# ...
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\malku\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
